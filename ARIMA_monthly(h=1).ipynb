# %%
import optuna
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from statsforecast import StatsForecast
from statsforecast.models import ARIMA
from utilsforecast.evaluation import evaluate

import warnings
import logging

warnings.filterwarnings("ignore", category=FutureWarning)
logging.getLogger("optuna").setLevel(logging.WARNING)
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %%
# Definir las métricas
def smape(y_true, y_pred):
    return 100 * np.mean(2 * np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred)))

def mape(y_true, y_pred):
    return 100 * np.mean(np.abs((y_true - y_pred) / y_true))

def mse(y_true, y_pred):
    return np.mean((y_true - y_pred) ** 2)

def mae(y_true, y_pred):
    return np.mean(np.abs(y_true - y_pred))

def rmse(y_true, y_pred):
    return np.sqrt(mse(y_true, y_pred))

def evaluate(cv_df, metrics):
    results = {}
    for metric in metrics:
        y_true = cv_df['y'].values
        y_pred = cv_df['ARIMA'].values
        results[metric.__name__] = metric(y_true, y_pred)
    return results

# %%
# Descargar datos
tickers = ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'NVDA', 'META', 'IBM', 'BTC-USD']
Y_df = yf.download(tickers, start='2000-01-01', interval='1mo')['Adj Close']

# Resetear el índice y transformar el DataFrame
Y_df = Y_df.reset_index().melt(id_vars='Date', var_name='unique_id', value_name='y')
Y_df = Y_df.rename(columns={'Date': 'ds'})
Y_df = Y_df[['unique_id', 'ds', 'y']]
Y_df = Y_df.dropna(subset=['y']).reset_index(drop=True)
# Out:
# [*********************100%%**********************]  8 of 8 completed

# %%
horizon = 1

# %%
def optimize_for_ticker(ticker):
    Y_df_ticker = Y_df[Y_df['unique_id'] == ticker]
    
    # Verifica el número de observaciones
    print(f"Number of observations for {ticker}: {len(Y_df_ticker)}")
    
    # Manejo de NaN
    if Y_df_ticker['y'].isnull().any():
        print(f"NaN values found in {ticker}.")
        return None  # Manejar según sea necesario

    # Definir función objetivo para Optuna
    def objective(trial):
        # Definir el espacio de búsqueda de hiperparámetros
        order = (trial.suggest_int('p', 0, 3), 
                 trial.suggest_int('d', 0, 2), 
                 trial.suggest_int('q', 0, 3))
        seasonal_order = (trial.suggest_int('P', 0, 3), 
                          trial.suggest_int('D', 0, 2), 
                          trial.suggest_int('Q', 0, 3))
        season_length = trial.suggest_int('season_length', 1, min(12, len(Y_df_ticker)))

        # Instanciar el modelo ARIMA
        model = ARIMA(order=order, 
                      seasonal_order=seasonal_order, 
                      season_length=season_length)

        # Instanciar StatsForecast
        sf = StatsForecast(df=Y_df_ticker, models=[model], freq='MS', n_jobs=-1)

        cv_df = sf.cross_validation(df=Y_df_ticker, h=horizon, step_size=horizon, n_windows=5)
        cv_df = cv_df.reset_index()

        # Evaluar las predicciones
        evaluation_results = evaluate(cv_df.loc[:, cv_df.columns != 'cutoff'], metrics=[smape, mape, mse, mae, rmse])

        # Obtener SMAPE para la optimización
        smape_value = evaluation_results['smape']
        mape_value = evaluation_results['mape']
        mse_value = evaluation_results['mse']
        mae_value = evaluation_results['mae']
        rmse_value = evaluation_results['rmse']

        return smape_value, mape_value, mse_value, mae_value, rmse_value

    # Configurar y ejecutar la optimización con Optuna
    study = optuna.create_study(direction='minimize')
    study.optimize(objective, n_trials=25)

    # Mostrar los mejores parámetros
    best_params = study.best_params
    print(f"Best hyperparameters for {ticker}: {best_params}")
    print(f"Best SMAPE for {ticker}: {study.best_value}")

    return best_params

# %%
def create_model_and_predict(ticker, best_params):
    Y_df_ticker = Y_df[Y_df['unique_id'] == ticker]

    # Crear y ajustar el modelo final con los mejores parámetros
    final_model = ARIMA(
        order=(best_params['p'], best_params['d'], best_params['q']),
        seasonal_order=(best_params['P'], best_params['D'], best_params['Q']),
        season_length=best_params['season_length']
    )

    # Instanciar StatsForecast con el modelo final
    sf_final = StatsForecast(df=Y_df_ticker, models=[final_model], freq='MS', n_jobs=-1)

    prediction_length = int(len(Y_df_ticker)) - horizon
    Y_df_real = Y_df_ticker[:prediction_length]
    Y_df_test = Y_df_ticker[prediction_length:]

    # Ajustar el modelo
    sf_final.fit(Y_df_real)

    # Realizar predicciones
    forecast = sf_final.forecast(h=horizon)
    
    print(f"Predictions for {ticker}:")
    print(forecast)

    return forecast

# %%
def plot_predictions(ticker, forecast):
    Y_df_ticker = Y_df[Y_df['unique_id'] == ticker]
    
    # Graficar
    plt.figure(figsize=(10, 5))

    # Datos reales
    real_series = Y_df_ticker[['ds', 'y']]  
    plt.plot(real_series['ds'], real_series['y'], label='Actual Data', linestyle='-', color='blue', linewidth=2)

    # Predicciones
    forecast_series = forecast[['ds', 'ARIMA']]
    plt.plot(forecast_series['ds'], forecast_series['ARIMA'], label='Prediction', marker='x', color='orange')

    # Configurar el gráfico
    plt.title(f'Predictions vs Actual Data for {ticker}', fontsize=14)  
    plt.xlabel('Date', fontsize=12)
    plt.ylabel('Value', fontsize=12)
    plt.legend(fontsize=10)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.grid(visible=True, linestyle='--', alpha=0.5)

    # Mostrar el gráfico
    plt.show()

# %%
# Diccionario para almacenar los mejores parámetros
best_params_dict = {}

for ticker in tickers:
    print(f"\nOptimizando para {ticker}...")
    best_params = optimize_for_ticker(ticker)
    
    # Guardamos los mejores parámetros en el diccionario
    best_params_dict[ticker] = best_params
# Out:
# Optimizando para AAPL...
# Number of observations for AAPL: 298
# [W 2024-10-07 14:08:51,728] Trial 0 failed with parameters: {'p': 2, 'd': 0, 'q': 0, 'P': 1, 'D': 2, 'Q': 1, 'season_length': 10} because of the following error: The number of the values 5 did not match the number of the objectives 1.
# [W 2024-10-07 14:08:51,733] Trial 0 failed with value (6.360176205635071, 6.139461323618889, 255.32178, 13.758017, 15.978791).
# [W 2024-10-07 14:09:53,387] Trial 1 failed with parameters: {'p': 2, 'd': 0, 'q': 3, 'P': 1, 'D': 1, 'Q': 2, 'season_length': 12} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/optuna/study/_optimize.py", line 196, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/var/folders/dt/cxyz36h16ydfv1yg6n6v5fqm0000gn/T/ipykernel_3585/3635146723.py", line 31, in objective
#     cv_df = sf.cross_validation(df=Y_df_ticker, h=horizon, step_size=horizon, n_windows=5)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/statsforecast/core.py", line 1677, in cross_validation
#     return super().cross_validation(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/statsforecast/core.py", line 1079, in cross_validation
#     res_fcsts = self.ga.cross_validation(
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/statsforecast/core.py", line 323, in cross_validation
#     res_i = model.forecast(**forecast_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/statsforecast/models.py", line 1571, in forecast
#     mod = Arima(
#           ^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/statsforecast/arima.py", line 1513, in Arima
#     tmp = arima(
#           ^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/statsforecast/arima.py", line 971, in arima
#     res = minimize(
#           ^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/optimize/_minimize.py", line 708, in minimize
#     res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/optimize/_optimize.py", line 1503, in _minimize_bfgs
#     _line_search_wolfe12(f, myfprime, xk, pk, gfk,
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/optimize/_optimize.py", line 1239, in _line_search_wolfe12
#     ret = line_search_wolfe1(f, fprime, xk, pk, gfk,
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/optimize/_linesearch.py", line 94, in line_search_wolfe1
#     stp, fval, old_fval = scalar_search_wolfe1(
#                           ^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/optimize/_linesearch.py", line 171, in scalar_search_wolfe1
#     stp, phi1, phi0, task = dcsrch(
#                             ^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/optimize/_dcsrch.py", line 256, in __call__
#     derphi1 = self.derphi(stp)
#               ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/optimize/_linesearch.py", line 88, in derphi
#     gval[0] = fprime(xk + s*pk, *args)
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py", line 284, in grad
#     self._update_grad()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py", line 267, in _update_grad
#     self._update_grad_impl()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py", line 181, in update_grad
#     self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/optimize/_numdiff.py", line 519, in approx_derivative
#     return _dense_difference(fun_wrapped, x0, f0, h,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/optimize/_numdiff.py", line 590, in _dense_difference
#     df = fun(x) - f0
#          ^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/optimize/_numdiff.py", line 470, in fun_wrapped
#     f = np.atleast_1d(fun(x, *args, **kwargs))
#                       ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py", line 145, in fun_wrapped
#     fx = fun(np.copy(x), *args)
#          ^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/statsforecast/arima.py", line 682, in armafn
#     res = arima_like(
#           ^^^^^^^^^^^
# KeyboardInterrupt
# [W 2024-10-07 14:09:53,412] Trial 1 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[52], line 6
#       4 for ticker in tickers:
#       5     print(f"\nOptimizando para {ticker}...")
# ----> 6     best_params = optimize_for_ticker(ticker)
#       8     # Guardamos los mejores parámetros en el diccionario
#       9     best_params_dict[ticker] = best_params
#
# Cell In[49], line 48, in optimize_for_ticker(ticker)
#      46 # Configurar y ejecutar la optimización con Optuna
#      47 study = optuna.create_study(direction='minimize')
# ---> 48 study.optimize(objective, n_trials=25)
#      50 # Mostrar los mejores parámetros
#      51 best_params = study.best_params
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/optuna/study/study.py:451, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     348 def optimize(
#     349     self,
#     350     func: ObjectiveFuncType,
#    (...)
#     357     show_progress_bar: bool = False,
#     358 ) -> None:
#     359     """Optimize an objective function.
#     360
#     361     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     449             If nested invocation of this method occurs.
#     450     """
# --> 451     _optimize(
#     452         study=self,
#     453         func=func,
#     454         n_trials=n_trials,
#     455         timeout=timeout,
#     456         n_jobs=n_jobs,
#     457         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     458         callbacks=callbacks,
#     459         gc_after_trial=gc_after_trial,
#     460         show_progress_bar=show_progress_bar,
#     461     )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/optuna/study/_optimize.py:62, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      60 try:
#      61     if n_jobs == 1:
# ---> 62         _optimize_sequential(
#      63             study,
#      64             func,
#      65             n_trials,
#      66             timeout,
#      67             catch,
#      68             callbacks,
#      69             gc_after_trial,
#      70             reseed_sampler_rng=False,
#      71             time_start=None,
#      72             progress_bar=progress_bar,
#      73         )
#      74     else:
#      75         if n_jobs == -1:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/optuna/study/_optimize.py:159, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     156         break
#     158 try:
# --> 159     frozen_trial = _run_trial(study, func, catch)
#     160 finally:
#     161     # The following line mitigates memory problems that can be occurred in some
#     162     # environments (e.g., services that use computing containers such as GitHub Actions).
#     163     # Please refer to the following PR for further details:
#     164     # https://github.com/optuna/optuna/pull/325.
#     165     if gc_after_trial:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/optuna/study/_optimize.py:247, in _run_trial(study, func, catch)
#     240         assert False, "Should not reach."
#     242 if (
#     243     frozen_trial.state == TrialState.FAIL
#     244     and func_err is not None
#     245     and not isinstance(func_err, catch)
#     246 ):
# --> 247     raise func_err
#     248 return frozen_trial
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/optuna/study/_optimize.py:196, in _run_trial(study, func, catch)
#     194 with get_heartbeat_thread(trial._trial_id, study._storage):
#     195     try:
# --> 196         value_or_values = func(trial)
#     197     except exceptions.TrialPruned as e:
#     198         # TODO(mamu): Handle multi-objective cases.
#     199         state = TrialState.PRUNED
#
# Cell In[49], line 31, in optimize_for_ticker.<locals>.objective(trial)
#      28 # Instanciar StatsForecast
#      29 sf = StatsForecast(df=Y_df_ticker, models=[model], freq='MS', n_jobs=-1)
# ---> 31 cv_df = sf.cross_validation(df=Y_df_ticker, h=horizon, step_size=horizon, n_windows=5)
#      32 cv_df = cv_df.reset_index()
#      34 # Evaluar las predicciones
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/statsforecast/core.py:1677, in StatsForecast.cross_validation(self, h, df, n_windows, step_size, test_size, input_size, level, fitted, refit, sort_df, prediction_intervals, id_col, time_col, target_col)
#    1659 def cross_validation(
#    1660     self,
#    1661     h: int,
#    (...)
#    1674     target_col: str = "y",
#    1675 ):
#    1676     if self._is_native(df=df):
# -> 1677         return super().cross_validation(
#    1678             h=h,
#    1679             df=df,
#    1680             n_windows=n_windows,
#    1681             step_size=step_size,
#    1682             test_size=test_size,
#    1683             input_size=input_size,
#    1684             level=level,
#    1685             fitted=fitted,
#    1686             refit=refit,
#    1687             sort_df=sort_df,
#    1688             prediction_intervals=prediction_intervals,
#    1689             id_col=id_col,
#    1690             time_col=time_col,
#    1691             target_col=target_col,
#    1692         )
#    1693     assert df is not None
#    1694     engine = make_execution_engine(infer_by=[df])
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/statsforecast/core.py:1079, in _StatsForecast.cross_validation(self, h, df, n_windows, step_size, test_size, input_size, level, fitted, refit, sort_df, prediction_intervals, id_col, time_col, target_col)
#    1077 _, level = self._parse_X_level(h=h, X=None, level=level)
#    1078 if self.n_jobs == 1:
# -> 1079     res_fcsts = self.ga.cross_validation(
#    1080         models=self.models,
#    1081         h=h,
#    1082         test_size=test_size,
#    1083         fallback_model=self.fallback_model,
#    1084         step_size=step_size,
#    1085         input_size=input_size,
#    1086         fitted=fitted,
#    1087         level=level,
#    1088         verbose=self.verbose,
#    1089         refit=refit,
#    1090         target_col=target_col,
#    1091     )
#    1092 else:
#    1093     res_fcsts = self._cross_validation_parallel(
#    1094         h=h,
#    1095         test_size=test_size,
#    (...)
#    1101         target_col=target_col,
#    1102     )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/statsforecast/core.py:323, in GroupedArray.cross_validation(self, models, h, test_size, fallback_model, step_size, input_size, fitted, level, refit, verbose, target_col)
#     314 forecast_kwargs = dict(
#     315     h=h,
#     316     y=y_train,
#    (...)
#     320     **kwargs,
#     321 )
#     322 try:
# --> 323     res_i = model.forecast(**forecast_kwargs)
#     324 except Exception as error:
#     325     if fallback_model is None:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/statsforecast/models.py:1571, in ARIMA.forecast(self, y, h, X, X_future, level, fitted)
#    1544 """Memory efficient predictions.
#    1545
#    1546 This method avoids memory burden due from object storage.
#    (...)
#    1568     Dictionary with entries `mean` for point predictions and `level_*` for probabilistic predictions.
#    1569 """
#    1570 with np.errstate(invalid="ignore"):
# -> 1571     mod = Arima(
#    1572         x=y,
#    1573         order=self.order,
#    1574         seasonal={"order": self.seasonal_order, "period": self.season_length},
#    1575         xreg=X,
#    1576         include_mean=self.include_mean,
#    1577         include_constant=self.include_constant,
#    1578         include_drift=self.include_drift,
#    1579         blambda=self.blambda,
#    1580         biasadj=self.biasadj,
#    1581         method=self.method,
#    1582         fixed=self.fixed,
#    1583     )
#    1584 fcst = forecast_arima(mod, h, xreg=X_future, level=level)
#    1585 res = {"mean": fcst["mean"]}
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/statsforecast/arima.py:1513, in Arima(x, order, seasonal, xreg, include_mean, include_drift, include_constant, blambda, biasadj, method, model, **kwargs)
#    1511             kwargs["fixed"] = change_drift_name(kwargs["fixed"], inverse=True)
#    1512 if xreg is None:
# -> 1513     tmp = arima(
#    1514         x,
#    1515         order=order,
#    1516         seasonal=seasonal,
#    1517         include_mean=include_mean,
#    1518         method=method,
#    1519         **kwargs
#    1520     )
#    1521 else:
#    1522     tmp = arima(
#    1523         x,
#    1524         order=order,
#    (...)
#    1529         **kwargs
#    1530     )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/statsforecast/arima.py:971, in arima(x, order, seasonal, xreg, include_mean, transform_pars, fixed, init, method, SSinit, optim_method, kappa, tol, optim_control)
#     963     res = OptimResult(
#     964         True,
#     965         0,
#    (...)
#     968         np.array([]),
#     969     )
#     970 else:
# --> 971     res = minimize(
#     972         armafn,
#     973         init[mask],
#     974         args=(
#     975             x,
#     976             transform_pars,
#     977         ),
#     978         method=optim_method,
#     979         tol=tol,
#     980         options=optim_control,
#     981     )
#     982 coef[mask] = res.x
#     983 if transform_pars:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/optimize/_minimize.py:708, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     706     res = _minimize_cg(fun, x0, args, jac, callback, **options)
#     707 elif meth == 'bfgs':
# --> 708     res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     709 elif meth == 'newton-cg':
#     710     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     711                              **options)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/optimize/_optimize.py:1503, in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, finite_diff_rel_step, xrtol, c1, c2, hess_inv0, **unknown_options)
#    1500 pk = -np.dot(Hk, gfk)
#    1501 try:
#    1502     alpha_k, fc, gc, old_fval, old_old_fval, gfkp1 = \
# -> 1503              _line_search_wolfe12(f, myfprime, xk, pk, gfk,
#    1504                                   old_fval, old_old_fval, amin=1e-100,
#    1505                                   amax=1e100, c1=c1, c2=c2)
#    1506 except _LineSearchError:
#    1507     # Line search failed to find a better solution.
#    1508     warnflag = 2
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/optimize/_optimize.py:1239, in _line_search_wolfe12(f, fprime, xk, pk, gfk, old_fval, old_old_fval, **kwargs)
#    1225 """
#    1226 Same as line_search_wolfe1, but fall back to line_search_wolfe2 if
#    1227 suitable step length is not found, and raise an exception if a
#    (...)
#    1234
#    1235 """
#    1237 extra_condition = kwargs.pop('extra_condition', None)
# -> 1239 ret = line_search_wolfe1(f, fprime, xk, pk, gfk,
#    1240                          old_fval, old_old_fval,
#    1241                          **kwargs)
#    1243 if ret[0] is not None and extra_condition is not None:
#    1244     xp1 = xk + ret[0] * pk
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/optimize/_linesearch.py:94, in line_search_wolfe1(f, fprime, xk, pk, gfk, old_fval, old_old_fval, args, c1, c2, amax, amin, xtol)
#      90     return np.dot(gval[0], pk)
#      92 derphi0 = np.dot(gfk, pk)
# ---> 94 stp, fval, old_fval = scalar_search_wolfe1(
#      95         phi, derphi, old_fval, old_old_fval, derphi0,
#      96         c1=c1, c2=c2, amax=amax, amin=amin, xtol=xtol)
#      98 return stp, fc[0], gc[0], fval, old_fval, gval[0]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/optimize/_linesearch.py:171, in scalar_search_wolfe1(phi, derphi, phi0, old_phi0, derphi0, c1, c2, amax, amin, xtol)
#     168 maxiter = 100
#     170 dcsrch = DCSRCH(phi, derphi, c1, c2, xtol, amin, amax)
# --> 171 stp, phi1, phi0, task = dcsrch(
#     172     alpha1, phi0=phi0, derphi0=derphi0, maxiter=maxiter
#     173 )
#     175 return stp, phi1, phi0
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/optimize/_dcsrch.py:256, in DCSRCH.__call__(self, alpha1, phi0, derphi0, maxiter)
#     254     alpha1 = stp
#     255     phi1 = self.phi(stp)
# --> 256     derphi1 = self.derphi(stp)
#     257 else:
#     258     break
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/optimize/_linesearch.py:88, in line_search_wolfe1.<locals>.derphi(s)
#      87 def derphi(s):
# ---> 88     gval[0] = fprime(xk + s*pk, *args)
#      89     gc[0] += 1
#      90     return np.dot(gval[0], pk)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:284, in ScalarFunction.grad(self, x)
#     282 if not np.array_equal(x, self.x):
#     283     self._update_x_impl(x)
# --> 284 self._update_grad()
#     285 return self.g
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:267, in ScalarFunction._update_grad(self)
#     265 def _update_grad(self):
#     266     if not self.g_updated:
# --> 267         self._update_grad_impl()
#     268         self.g_updated = True
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:181, in ScalarFunction.__init__.<locals>.update_grad()
#     179 self._update_fun()
#     180 self.ngev += 1
# --> 181 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#     182                            **finite_diff_options)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/optimize/_numdiff.py:519, in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     516     use_one_sided = False
#     518 if sparsity is None:
# --> 519     return _dense_difference(fun_wrapped, x0, f0, h,
#     520                              use_one_sided, method)
#     521 else:
#     522     if not issparse(sparsity) and len(sparsity) == 2:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/optimize/_numdiff.py:590, in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     588     x = x0 + h_vecs[i]
#     589     dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 590     df = fun(x) - f0
#     591 elif method == '3-point' and use_one_sided[i]:
#     592     x1 = x0 + h_vecs[i]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/optimize/_numdiff.py:470, in approx_derivative.<locals>.fun_wrapped(x)
#     467 if xp.isdtype(x.dtype, "real floating"):
#     468     x = xp.astype(x, x0.dtype)
# --> 470 f = np.atleast_1d(fun(x, *args, **kwargs))
#     471 if f.ndim > 1:
#     472     raise RuntimeError("`fun` return value has "
#     473                        "more than 1 dimension.")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:145, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     141 self.nfev += 1
#     142 # Send a copy because the user may overwrite it.
#     143 # Overwriting results in undefined behaviour because
#     144 # fun(self.x) will change self.x, with the two no longer linked.
# --> 145 fx = fun(np.copy(x), *args)
#     146 # Make sure the function returns a true scalar
#     147 if not np.isscalar(fx):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/statsforecast/arima.py:682, in arima.<locals>.armafn(p, x, trans)
#     680 if ncxreg > 0:
#     681     x -= np.dot(xreg, par[narma + np.arange(ncxreg)])
# --> 682 res = arima_like(
#     683     x,
#     684     Z["phi"],
#     685     Z["theta"],
#     686     Z["delta"],
#     687     Z["a"],
#     688     Z["P"],
#     689     Z["Pn"],
#     690     0,
#     691     False,
#     692 )
#     693 if res[2] == 0.0:
#     694     return math.inf
#
# KeyboardInterrupt:

# %%
import time

# Diccionario para almacenar las predicciones
forecasts_dict = {}

for ticker in tickers:
    print(f"\nCreando el modelo y realizando predicciones para {ticker}...")
    
    predict_start = time.time()
    print(f"Generando predicción para {ticker}")
    
    # Usamos los mejores parámetros almacenados para cada ticker
    best_params = best_params_dict[ticker]
    
    # Creamos el modelo y realizamos las predicciones
    forecast = create_model_and_predict(ticker, best_params)

    predict_end = time.time()

    # Calcular el tiempo de predicción
    predict_time = predict_end - predict_start
    print(f"Tiempo de predicción: {predict_time:.2f} segundos")
    
    # Guardamos las predicciones en el diccionario
    forecasts_dict[ticker] = forecast
# Out:
# Creando el modelo y realizando predicciones para AAPL...
# Generando predicción para AAPL
# Predictions for AAPL:
#                   ds       ARIMA
# unique_id
# AAPL      2024-10-01  240.968903
# Tiempo de predicción: 4.48 segundos
#
# Creando el modelo y realizando predicciones para MSFT...
# Generando predicción para MSFT
# Predictions for MSFT:
#                   ds       ARIMA
# unique_id
# MSFT      2024-10-01  427.305237
# Tiempo de predicción: 0.81 segundos
#
# Creando el modelo y realizando predicciones para GOOGL...
# Generando predicción para GOOGL
# Predictions for GOOGL:
#                   ds      ARIMA
# unique_id
# GOOGL     2024-10-01  162.17627
# Tiempo de predicción: 4.15 segundos
#
# Creando el modelo y realizando predicciones para AMZN...
# Generando predicción para AMZN
# Predictions for AMZN:
#                   ds       ARIMA
# unique_id
# AMZN      2024-10-01  183.867294
# Tiempo de predicción: 3.58 segundos
#
# Creando el modelo y realizando predicciones para NVDA...
# Generando predicción para NVDA
# Predictions for NVDA:
#                   ds       ARIMA
# unique_id
# NVDA      2024-10-01  125.185242
# Tiempo de predicción: 1.52 segundos
#
# Creando el modelo y realizando predicciones para META...
# Generando predicción para META
# Predictions for META:
#                   ds       ARIMA
# unique_id
# META      2024-10-01  610.811462
# Tiempo de predicción: 1.11 segundos
#
# Creando el modelo y realizando predicciones para IBM...
# Generando predicción para IBM
# Predictions for IBM:
#                   ds       ARIMA
# unique_id
# IBM       2024-10-01  214.435287
# Tiempo de predicción: 0.83 segundos
#
# Creando el modelo y realizando predicciones para BTC-USD...
# Generando predicción para BTC-USD
# Predictions for BTC-USD:
#                   ds         ARIMA
# unique_id
# BTC-USD   2024-10-01  63080.492188
# Tiempo de predicción: 0.33 segundos

# %%
for ticker in tickers:
    print(f"\nGraficando las predicciones para {ticker}...")
    
    # Usamos las predicciones almacenadas para cada ticker
    forecast = forecasts_dict[ticker]
    
    # Graficamos las predicciones
    plot_predictions(ticker, forecast)
# Out:
# Graficando las predicciones para AAPL...
# Graficando las predicciones para MSFT...
# Graficando las predicciones para GOOGL...
# Graficando las predicciones para AMZN...
# Graficando las predicciones para NVDA...
# Graficando las predicciones para META...
# Graficando las predicciones para IBM...
# Graficando las predicciones para BTC-USD...
